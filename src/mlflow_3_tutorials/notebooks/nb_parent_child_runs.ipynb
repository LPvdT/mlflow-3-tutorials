# %% [markdown]
# # Leveraging Child Runs in MLflow for Hyperparameter Tuning
#
# In the world of machine learning, the task of hyperparameter tuning is central to model optimization. This process involves performing multiple runs with varying parameters to identify the most effective combination, ultimately enhancing model performance. However, this can lead to a large volume of runs, making it challenging to track, organize, and compare these experiments effectively.
#
# **MLflow** incorporates the ability to simplify the large-data-volume issue by offering a structured approach to manage this complexity. In this notebook, we will explore the concept of **Parent and Child Runs** in MLflow, a feature that provides a hierarchical structure to organize runs. This hierarchy allows us to bundle a set of runs under a parent run, making it much more manageable and intuitive to analyze and compare the results of different hyperparameter combinations. This structure proves to be especially beneficial in understanding and visualizing the outcomes of hyperparameter tuning processes.
#
# Throughout this notebook, we will:
# - Understand the usage and benefits of parent and child runs in MLflow.
# - Walk through a practical example demonstrating the organization of runs without and with child runs.
# - Observe how child runs aid in effectively tracking and comparing the results of different parameter combinations.
# - Demonstrate a further refinement by having the parent run maintain the state of the best conditions from child run iterations.

# %% [markdown]
# ### Starting Without Child Runs
#
# Before diving into the structured world of parent and child runs, let’s begin by observing the scenario without utilizing child runs in MLflow. In this section, we perform multiple runs with different parameters and metrics without associating them as child runs of a parent run.
#
# Below is the code executing five hyperparameter tuning runs. These runs are not organized as child runs, and hence, each run is treated as an independent entity in MLflow. We will observe the challenges this approach poses in tracking and comparing runs, setting the stage for the introduction of child runs in the subsequent sections.
#
# After running the above code, you can proceed to the MLflow UI to view the logged runs. Observing the organization (or lack thereof) of these runs will help in appreciating the structured approach offered by using child runs, which we will explore in the next sections of this notebook.

# %%
from collections.abc import Sequence, Generator
from functools import partial
from itertools import starmap
from typing import Any
import numpy as np
from more_itertools import consume

import mlflow

from mlflow_3_tutorials.lib.constants import TRACKING_URI

# %%
rng = np.random.default_rng(420)


# Define a function to log parameters and metrics
def log_run(run_name: str, _test_no: Any) -> None:
    with mlflow.start_run(run_name=run_name):
        mlflow.log_param("param1", rng.choice(["a", "b", "c"]))
        mlflow.log_param("param2", rng.choice(["d", "e", "f"]))
        mlflow.log_metric("metric1", rng.uniform(0, 1))
        mlflow.log_metric("metric2", abs(rng.normal(5, 2.5)))


# Generate run names
def generate_run_names(
    test_no: Any, num_runs: int = 5
) -> Generator[str, None, None]:
    return (f"run_{i}_test_{test_no}" for i in range(num_runs))


# Execute tuning function
def execute_tuning(test_no: Any) -> None:
    # Partial application of the log_run function
    log_current_run = partial(log_run, _test_no=test_no)
    # Generate run names and apply log_current_run function to each run name
    runs = starmap(
        log_current_run,
        ((run_name,) for run_name in generate_run_names(test_no)),
    )
    # Consume the iterator to execute the runs
    consume(runs)


# Set the tracking uri and experiment
mlflow.set_tracking_uri(TRACKING_URI)
mlflow.set_experiment("No Child Runs")

# Execute 5 hyperparameter tuning runs
consume(starmap(execute_tuning, ((x,) for x in range(5))))
# Out:
# 2025/08/09 11:24:04 INFO mlflow.tracking.fluent: Experiment with name 'No Child Runs' does not exist. Creating a new experiment.
# 🏃 View run run_0_test_0 at: http://127.0.0.1:5000/#/experiments/341979287022582382/runs/aab06048c795455bb91c1daa3d3d3592
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/341979287022582382
# 🏃 View run run_1_test_0 at: http://127.0.0.1:5000/#/experiments/341979287022582382/runs

# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/341979287022582382

# %% [markdown]
# ### Using Child Runs for Improved Organization
#
# As we proceed, the spotlight now shifts to the utilization of **Child Runs in MLflow**. This feature brings forth an organized structure, inherently solving the challenges we observed in the previous section. The child runs are neatly nested under a parent run, providing a clear, hierarchical view of all the runs, making it exceptionally convenient to analyze and compare the outcomes.
#
# #### Benefits of Using Child Runs:
# - **Structured View:** The child runs, grouped under a parent run, offer a clean and structured view in the MLflow UI.
# - **Efficient Filtering:** The hierarchical organization facilitates efficient filtering and selection, enhancing the usability of the MLflow UI and search APIs.
# - **Distinct Naming:** Utilizing visually distinct naming for runs aids in effortless identification and selection within the UI.
#
# In this section, the code is enhanced to use child runs. Each `execute_tuning` function call creates a parent run, under which multiple child runs are nested. These child runs are performed with different parameters and metrics. Additionally, we incorporate tags to further enhance the search and filter capabilities in MLflow.
#
# Notice the inclusion of the `nested=True` parameter in the `mlflow.start_run()` function, indicating the creation of a child run. The addition of tags, using the `mlflow.set_tag()` function, provides an extra layer of information, useful for filtering and searching runs effectively.
#
# Let's dive into the code and observe the seamless organization and enhanced functionality brought about by the use of child runs in MLflow.

# %%
# Define a function to log parameters and metrics and add tag
# logging for search_runs functionality


def log_run_2(
    run_name: str,
    _test_no: Any,
    param1_choices: Sequence,
    param2_choices: Sequence,
    tag_ident: Any,
) -> None:
    with mlflow.start_run(run_name=run_name, nested=True):
        mlflow.log_param("param1", rng.choice(param1_choices))
        mlflow.log_param("param2", rng.choice(param2_choices))
        mlflow.log_metric("metric1", rng.uniform(0, 1))
        mlflow.log_metric("metric2", abs(rng.normal(5, 2.5)))
        mlflow.set_tag("test_identifier", tag_ident)


# Execute tuning function, allowing for param overrides,
# run_name disambiguation, and tagging support
def execute_tuning(
    test_no: Any,
    param1_choices: Sequence = ("a", "b", "c"),
    param2_choices: Sequence = ("d", "e", "f"),
    test_identifier: str = "",
) -> None:
    ident = test_identifier or "default"
    # Use a parent run to encapsulate the child runs
    with mlflow.start_run(run_name=f"parent_run_test_{ident}_{test_no}"):
        # Partial application of the log_run function
        log_current_run = partial(
            log_run_2,
            _test_no=test_no,
            param1_choices=param1_choices,
            param2_choices=param2_choices,
            tag_ident=ident,
        )
        mlflow.set_tag("test_identifier", ident)
        # Generate run names and apply log_current_run function to each run name
        runs = starmap(
            log_current_run,
            ((run_name,) for run_name in generate_run_names(test_no)),
        )
        # Consume the iterator to execute the runs
        consume(runs)


# Set experiment
mlflow.set_experiment("Nested Child Association")

# Define custom parameters
param_1_values = ["x", "y", "z"]
param_2_values = ["u", "v", "w"]

# Execute hyperparameter tuning runs with custom parameter choices
consume(
    starmap(
        execute_tuning, ((x, param_1_values, param_2_values) for x in range(5))
    )
)
# Out:
# 2025/08/09 11:24:06 INFO mlflow.tracking.fluent: Experiment with name 'Nested Child Association' does not exist. Creating a new experiment.
# 🏃 View run run_0_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/177e871cc5ef41a396fd01f3e84858c1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/c7c1113e292e430c806eaf4d7bf2cf9b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/700d43da22ee4a22adf0ddc6b79062cd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/a0608dd6b001447ba964af7708ca78f4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/c00cb695d2d240af833971293036eea5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_default_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/a61e9ce5622b4f2487d8627ac34f6f22
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/7150e079fbc0499db8a8048450078a34
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/cb9d8c8a719f463c96865f7f7cbafd44
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/1c9c7e2610354c4fb95c04313eeceb36
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/8892cb2f5c4649898f81676e5847e797
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/4e916d1dc6a24a3aba03a5cf3e2e7374
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_default_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/d0c976985c6c4ee6bd087f148c7b90fa
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/568a482e467c4f0db58f5c2eaa645ab8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/30deb030309848618be69b5eccbd54af
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/0e312ecd36514ebd99c4e52fef2af181
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/337d5e8b59aa40a1b2ae4f2855e98d63
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/86b226d1d46d47c5bbe31a34e5feec4f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_default_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/312a949473cd45dbb9585a159dbdffdf
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/2cd3d9b2c4d44616a7782f37bf957ca3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/d0ef9552d4844304ade5396a0bef2252
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/a5fc1f94b4294ea9b028cc65e33007e5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/ba34efd20da743299d74b98de2165ba5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/9ad44c456bb14ef4a5876e7d2873897d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_default_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/c1d0c2756d8e4a8bb43020502fb542d8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/be72e748a0734cbba7396cee1d7265d5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/7557dcfa937d4f098d1a57088d1d9687
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/f11bced268784457b86ab61f9587b8e3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/dc684aaa9ac24e97bce891911daeb87a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/749cfacd5e7b41bc926498634dd7d711
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_default_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/4b44c18418354a38a3f1783f638554dd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579

# %% [markdown]
# ### Tailoring the Hyperparameter Tuning Process
#
# In this segment, we are taking a step further in our iterative process of hyperparameter tuning. Observe the execution of additional hyperparameter tuning runs, where we introduce **custom parameter choices** and a unique identifier for tagging.
#
# #### What Are We Doing?
# - **Custom Parameter Choices:** We are now employing different parameter values (`param_1_values` as `["x", "y", "z"]` and `param_2_values` as `["u", "v", "w"]`) for the runs.
# - **Unique Identifier for Tagging:** A distinct identifier (`ident`) is used for tagging, which provides an easy and efficient way to filter and search these specific runs in the MLflow UI.
#
# #### How Does It Apply to Hyperparameter Tuning?
# - **Parameter Sensitivity Analysis:** This step allows us to analyze the sensitivity of the model to different parameter values, aiding in a more informed and effective tuning process.
# - **Efficient Search and Filter:** The use of a unique identifier for tagging facilitates an efficient and quick search for these specific runs among a multitude of others, enhancing the user experience in the MLflow UI.
#
# This approach, employing custom parameters and tagging, enhances the clarity and efficiency of the hyperparameter tuning process, contributing to building a more robust and optimized model.
#
# Let's execute this section of the code and delve deeper into the insights and improvements it offers in the hyperparameter tuning process.

# %%
# Execute additional hyperparameter tuning runs with custom parameter choices
param_1_values = ["x", "y", "z"]
param_2_values = ["u", "v", "w"]
ident = "params_test_2"
consume(
    starmap(
        execute_tuning,
        ((x, param_1_values, param_2_values, ident) for x in range(5)),
    )
)
# Out:
# 🏃 View run run_0_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/4bfaeee74ab44167865a53f3f54e4a74
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/fdf00b9945624c35b1b8774c04df221e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/e087c3ba5908461088100888cb66f8cd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/ca9ee2b9dce6424890ca94f127feca0c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/4f618ef53f4f4fb0b53eb7b6664325cd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_params_test_2_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/050b19b9648d407fa2cd4f832eb061a4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/cc0574fe50b048f399c623d5d62f7f89
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/2f57053e9b4f42298a17c616d12acfcd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/2343b9461c304b39a70311bf2d207342
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/efd7b422fd0741bd89bb917fddeda466
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/1b4b0ed4a0d948eb96ff1d9884380f0e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_params_test_2_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/f82ce7e15d3341f08f0c4aeec2538aa5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/2d69d1c463de43a9a3e7ccad00ebe476
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/aed770bb579c4551b6be2540df34a9d0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/bf828bcbaf414cb6b88e17d07fcade78
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/aa9921ee0aad450881e977be37195345
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/0d7885070d4d4373ab41750c8512117b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_params_test_2_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/0391d229ce7e4a68bcb8fca214ec25c1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/7eb8eb77b87a46379a03057959762667
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/add0b6cc5d694a0a9c9545655a701e78
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/ff55f5d3b33a4eceb25b175445036fd2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/8ddf70b3cf23496b84a847a07af4ce67
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/99a0d1d971834a83867df089fa59d5d4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_params_test_2_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/d6f4ff9ebe7e4f09b31d28de6d9b26f1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/0c259259ae4d4029a9922703eeea8eb9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/d65d011cfe7446c9b27f93bdff304ae0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/a001c0b1465f44aab36e653088af3820
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/b36f9f06b43e4574af3c0133aa03a589
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/ac837a3bc7c542e983f167ff006ce12c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_params_test_2_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/cb2d33e9fb434b09937bff168b97bc11
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579

# %% [markdown]
# ### Refining the Hyperparameter Search Space
#
# In this phase, we focus on **refining the hyperparameter search space**. This is a crucial step in the hyperparameter tuning process. After a broad exploration of the parameter space, we are now narrowing down our search to a subset of parameter values.
#
# #### What Are We Doing?
# - **Sub-setting Parameter Values:** We are focusing on a more specific set of parameter values (`param_1_values` as `["b", "c"]` and `param_2_values` as `["d", "f"]`) based on insights gathered from previous runs.
# - **Tagging the Runs:** Using a unique identifier (`ident`) for tagging ensures easy filtering and searching of these runs in the MLflow UI.
#
# #### How Does It Apply to Hyperparameter Tuning?
# - **Focused Search:** This narrowed search allows us to deeply explore the interactions and impacts of a specific set of parameter values, potentially leading to more optimized models.
# - **Efficient Resource Utilization:** It enables more efficient use of computational resources by focusing the search on promising areas of the parameter space.
#
# #### Caution
# While this approach is a common tactic in hyperparameter tuning, it's crucial to acknowledge the implications. Comparing results from the narrowed search space directly with those from the original, broader search space can be misleading.
#
# #### Why Is It Invalid to Compare?
# - **Nature of Bayesian Tuning Algorithms:** Bayesian optimization and other tuning algorithms often depend on the exploration of a broad parameter space to make informed decisions. Restricting the parameter space can influence the behavior of these algorithms, leading to biased or suboptimal results.
# - **Interaction of Hyperparameter Selection Values:** Different parameter values have different interactions and impacts on the model performance. A narrowed search space may miss out on capturing these interactions, leading to incomplete or skewed insights.
#
# In conclusion, while refining the search space is essential for efficient and effective hyperparameter tuning, it's imperative to approach the comparison of results with caution, acknowledging the intricacies and potential biases involved.

# %%
param_1_values = ["b", "c"]
param_2_values = ["d", "f"]
ident = "params_test_3"
consume(
    starmap(
        execute_tuning,
        ((x, param_1_values, param_2_values, ident) for x in range(5)),
    )
)
# Out:
# 🏃 View run run_0_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/c7fb7bf64bb54e0684bdc89c59a270ff
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/498880fc91e8430286576e0a8d6c860a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/9e6a6146511f4bd4926616a885c0202a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/742096a3bf9b4bc0aff287034be9927f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/96f6a0fe33f34cb8aff014090327564e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_params_test_3_0 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/174f39bf5ddb49e9a263dcf892304ee7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/deb8a35029a54f70ac0264dc567ba8bb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/fff00f1591bf4297b4b2a867ded0b83c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/72e3e809e2334c23836908d35d00da2e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/826630e6fc444acba95b57d63903f1ff
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/f25bc850b23e48b9a1bf6f287899be7b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_params_test_3_1 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/cb099e4245f24802866e72ba0798dda1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/9a5f9be66c734121a68b0e9bda16739f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/c65f22e5650840588ba0a5560bc79a9d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/a9cc268a2a4340009df089577f962ca6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/466c30d83ec04221974cd33f4e74586b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/fb1d1579f4594c68a32d830fa364bd24
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_params_test_3_2 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/b5439ef169e2408a83d4fcd39b8ca25b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/70f5f4eb1a404724afb16a079d540bb1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/f5074b7e9eb54fac9713e6cce8c6adb7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/7a9cbf44f4d8427e9eb7cc0253739a63
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/67edd968d90540a2a75373f1a8a64fef
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/78fddf33e3d849848d682d264f4d1164
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_params_test_3_3 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/19bdcd1de415428e9286bacc04043579
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_0_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/b069c2e51c784995b6ff7465bc63594e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_1_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/132cf3578c6146e48fe9af2b6b713a50
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_2_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/b0c6b2ec1aaf47f5b723d344f5482e0f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_3_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/11c0e57562e440a581391adc3a2835d0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run run_4_test_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/13f5dd0eb2b84ed3abc4d887c158434f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579
# 🏃 View run parent_run_test_params_test_3_4 at: http://127.0.0.1:5000/#/experiments/205928172843601579/runs/f602251565714edc8d5fe9b4e533211d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/205928172843601579

# %% [markdown]
# ### Challenge: Logging Best Metrics and Parameters
#
# In the real world of machine learning, it is crucial to keep track of the best performing models and their corresponding parameters for easy comparison and reproduction. **Your challenge is to enhance the `execute_tuning` function to log the best metrics and parameters from the child runs in each parent run.** This way, you can easily compare the best-performing models across different parent runs within the MLflow UI.
#
# #### Your Task:
#
# 1. Modify the `execute_tuning` function such that for each parent run, it logs the best (minimum) `metric1` found among all its child runs.
# 2. Alongside the best `metric1`, also log the parameters `param1` and `param2` that yielded this best `metric1`.
# 3. Ensure that the `execute_tuning` function can accept a `num_child_runs` parameter to specify how many child iterations to perform per parent run.
#
# This is a common practice that allows you to keep your MLflow experiments organized and easily retrievable, making the model selection process smoother and more efficient.
#
# **Hint:** You might want to return values from the `log_run` function and use these returned values in the `execute_tuning` function to keep track of the best metrics and parameters.
#
# #### Note:
# Before moving on to the solution below, **give it a try yourself!** This exercise is a great opportunity to familiarize yourself with advanced features of MLflow and improve your MLOps skills. If you get stuck or want to compare your solution, you can scroll down to see a possible implementation.

# %%
# Define a function to log parameters and metrics and add tag
# logging for search_runs functionality
from typing import Any


def log_run_3(
    run_name: str,
    _test_no: Any,
    param1_choices: Sequence,
    param2_choices: Sequence,
    tag_ident: Any,
) -> tuple[Any, float, Any, Any] | None:
    with mlflow.start_run(run_name=run_name, nested=True) as run:
        param1 = rng.choice(param1_choices)
        param2 = rng.choice(param2_choices)
        metric1 = rng.uniform(0, 1)
        metric2 = abs(rng.normal(5, 2.5))

        mlflow.log_param("param1", param1)
        mlflow.log_param("param2", param2)
        mlflow.log_metric("metric1", metric1)
        mlflow.log_metric("metric2", metric2)
        mlflow.set_tag("test_identifier", tag_ident)

        return run.info.run_id, metric1, param1, param2


# Execute tuning function, allowing for param overrides,
# run_name disambiguation, and tagging support
def execute_tuning(
    test_no: Any,
    param1_choices: Sequence = ("a", "b", "c"),
    param2_choices: Sequence = ("d", "e", "f"),
    test_identifier: str = "",
    num_child_runs: int = 5,
) -> None:
    ident = test_identifier or "default"
    best_metric1 = float("inf")
    best_params = None
    # Use a parent run to encapsulate the child runs
    with mlflow.start_run(run_name=f"parent_run_test_{ident}_{test_no}"):
        # Partial application of the log_run function
        log_current_run = partial(
            log_run_3,
            _test_no=test_no,
            param1_choices=param1_choices,
            param2_choices=param2_choices,
            tag_ident=ident,
        )
        mlflow.set_tag("test_identifier", ident)
        # Generate run names and apply log_current_run function to each run name
        results = list(
            starmap(
                log_current_run,
                (
                    (run_name,)
                    for run_name in generate_run_names(test_no, num_child_runs)
                ),
            )
        )

        for _, metric1, param1, param2 in results:  # type: ignore
            if metric1 < best_metric1:
                best_metric1 = metric1
                best_params = (param1, param2)

        mlflow.log_metric("best_metric1", best_metric1)
        mlflow.log_param("best_param1", best_params[0])  # type: ignore
        mlflow.log_param("best_param2", best_params[1])  # type: ignore
        # Consume the iterator to execute the runs
        consume(results)


# Set experiment
mlflow.set_experiment("Parent Child Association Challenge")

param_1_values = ["a", "b"]
param_2_values = ["d", "f"]

# Execute hyperparameter tuning runs with custom parameter choices
consume(
    starmap(
        execute_tuning,
        (
            (x, param_1_values, param_2_values, "subset_test", 25)
            for x in range(5)
        ),
    )
)
# Out:
# 2025/08/09 11:24:11 INFO mlflow.tracking.fluent: Experiment with name 'Parent Child Association Challenge' does not exist. Creating a new experiment.
# 🏃 View run run_0_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/035097f463cf4972b6663c8a50ff5fc1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_1_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/c3f62992ac08475f92cf648e486ec042
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_2_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/17708cbb7089404583bf94016962695f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_3_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/eeb8d81d569046cc81490ec92bfe8664
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_4_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/cfeb15c2bae44bf78cb4ccc9e24428b6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_5_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/b3f6e745fdf44cb59d4c71a10f1ea168
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_6_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/540be207e6c647778ee8a071fc71977f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_7_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/c0fd8af1aaa94aec97182e4a4a26a751
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_8_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/d09963fef73940739db6e115ca8c57e5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_9_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/3aaf650688c141b697b733ada43707cb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_10_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/6a7d81112c87455189a01be07edbbc76
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_11_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/8ac992fae12342c4a0d6ead8104ee94d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_12_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/77bfda9fa3eb4c4985c2e079e89ecbdd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_13_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/f11f18d4940448dab0350965096aba2e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_14_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/e18eecc5fa734f4aaef8001aebd5b9a3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_15_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/86e5336e6f0f47b6a4a5abd298c44f92
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_16_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/5862f1b0f64047a2a3a2228607bcba4b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_17_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/5ed3fe20eea749469b88ddd6a10a92b2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_18_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/f3f5f233ae864e3ba964cb1695b87dd5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_19_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/918af2b17faf4f01a2a885d865451c8f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_20_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/ddca84b5aa434d6eb7ffe720d11bb1cd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_21_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/51db7f727dc1497fa11293a5b4067773
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_22_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs/909db1711c704d899462464df150efca
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/357205642987985974
# 🏃 View run run_23_test_0 at: http://127.0.0.1:5000/#/experiments/357205642987985974/runs